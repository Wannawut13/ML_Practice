# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('ML_dataset/pima-indians-diabetes.csv')
X= df.iloc[:,0:8]
y= df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9)

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train,y_train, epochs=200, batch_size=15)
_, accuracy = model.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/200
# 47/47 [==============================] - 0s 914us/step - loss: 12.2219 - accuracy: 0.4356
# Epoch 2/200
# 47/47 [==============================] - 0s 1ms/step - loss: 2.8224 - accuracy: 0.5890
# Epoch 3/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.5984 - accuracy: 0.6237
# Epoch 4/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.3315 - accuracy: 0.6179
# Epoch 5/200
# 47/47 [==============================] - 0s 1ms/step - loss: 1.0869 - accuracy: 0.6165
# Epoch 6/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.9274 - accuracy: 0.6208
# Epoch 7/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.8459 - accuracy: 0.6194
# Epoch 8/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.7866 - accuracy: 0.6324
# Epoch 9/200
# 47/47 [==============================] - 0s 1ms/step - loss: 0.7862 - accuracy: 0.6310
# Epoch 10/200
# ...

# %%
# make class predictions with the model
predictions = model.predict(X_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]

#for i in range(predictions.size):
    #print('Result %d (expected %d)' % (rounded[i], y_test.iloc[i]))
    
mse = mean_squared_error(rounded, y_test)
print('MSE:%.2f'%mse)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, predictions))
# Out:
# MSE:0.27
# Coefficient of determination: 0.10

# %%
#import scipy.stats
corr = []

#scipy.stats.pearsonr(x, y_train)    # Pearson's r

#scipy.stats.spearmanr(x,y_train)   # Spearman's rho

#scipy.stats.kendalltau(x, y_train)  # Kendall's tau
for i in range(8) :
    x= X.iloc[:,i]
    corr.append(x.corr(y,method='spearman'))
corr
Newdf = pd.DataFrame([X.iloc[:,0],X.iloc[:,1],X.iloc[:,2],X.iloc[:,5],X.iloc[:,6],X.iloc[:,7]]).T

# %%
#NX = Newdf
y = df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(Newdf, y, train_size=0.9)

# %%
model = Sequential()
model.add(Dense(8, input_dim=6, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='BinaryCrossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(X_train,y_train, epochs=300, batch_size=20)
_, accuracy = model.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/300
# 35/35 [==============================] - 1s 1ms/step - loss: 0.9411 - accuracy: 0.6107
# Epoch 2/300
# 35/35 [==============================] - 0s 901us/step - loss: 0.6702 - accuracy: 0.6440
# Epoch 3/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6611 - accuracy: 0.6368
# Epoch 4/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6606 - accuracy: 0.6252
# Epoch 5/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6545 - accuracy: 0.6498
# Epoch 6/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6525 - accuracy: 0.6498
# Epoch 7/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6465 - accuracy: 0.6498
# Epoch 8/300
# 35/35 [==============================] - 0s 945us/step - loss: 0.6487 - accuracy: 0.6570
# Epoch 9/300
# 35/35 [==============================] - 0s 1ms/step - loss: 0.6428 - accuracy: 0.6541
# Epoch 10/300
# ...

# %%
predictions = model.predict(X_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
count = 0
for i in range(predictions.size):
    #print('Result %d (expected %d)' % (rounded[i], y_test.iloc[i]))
    if(rounded[i]==y_test.iloc[i]):count=count+1

(count/i)*100
# Out:
# 73.68421052631578
